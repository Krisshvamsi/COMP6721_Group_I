# %% [markdown]
# Googlenet on Freiburg Dataset

# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as td
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from matplotlib import image
from matplotlib import pyplot
import time
import torch.optim as optim

# %%
def load_data(path, test_split, val_split, batch_size, input_size):
    
    transform_dict={'src':transforms.Compose([transforms.RandomHorizontalFlip(),transforms.ToTensor(),transforms.Normalize(mean=[0.5,0.5,0.5], std=[0.5,0.5,0.5])])}
    data1 = datasets.ImageFolder(root=path,transform=transform_dict['src'])
    test_size=int(len(data1)*test_split)
    val_size=int(len(data1)*val_split)
    train_size=len(data1)-val_size-test_size
    train_dataset,test_dataset,val_dataset=td.random_split(data1,[train_size,test_size,val_size])
    data_loader_train=td.DataLoader(train_dataset,batch_size,shuffle=True,drop_last=False,num_workers=0)
    data_loader_test=td.DataLoader(test_dataset,batch_size,shuffle=True,drop_last=False,num_workers=0)
    data_loader_val=td.DataLoader(val_dataset,batch_size,shuffle=True,drop_last=False,num_workers=0)  
    return data_loader_train, data_loader_test, data_loader_val

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_loader,test_loader,val_loader=load_data(path=r'/content/drive/MyDrive/Project/Dataset/Freiburg_dataset', 
                                          test_split=0.2,val_split= 0.2,batch_size=32, input_size=[256,256])

# %%
def plot_data_loader(data_loader, gridDims):
    
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = dataiter.next()
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(train_loader,(2,2))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'googlenet')
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
def train( model, train_loader,val_loader, criterion, optimizer,num_epochs):
      device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
      print("Device: {}".format(device))
      model.to(device)
      model.aux_logits=False
      total_steps = len(train_loader)
      t1 = time.time()
      accuracy1 = []
      loss1 = []
      val_acc=[]
      val_loss=[]
      for epoch in range(num_epochs):
          accu = 0
          lss = 0
          val_accu=0
          valid_loss=0
          for i,data in enumerate(train_loader):
              images, labels = data[0].to(device), data[1].to(device)
              # Forward pass
              outputs = model(images)
              loss = criterion(outputs, labels)
              # Backprop and optimisation
              optimizer.zero_grad()
              loss.backward()
              optimizer.step()
              # Train accuracy
              total = labels.size(0)
              _,predicted = torch.max(outputs.data, 1)
              correct = (predicted == labels).sum().item()
              accu += (correct / total) * 100
              lss += loss.item()
          accuracy1.append(accu/len(train_loader))
          loss1.append(lss/len(train_loader))
          model.eval()  
          for i, data in enumerate(val_loader):
              val_images, val_labels = data[0].to(device), data[1].to(device)
              outputs = model(val_images)
              loss = criterion(outputs, val_labels)
              # Val accuracy
              total = val_labels.size(0)
              _,predicted = torch.max(outputs.data, 1)
              correct = (predicted == val_labels).sum().item()
              val_accu += (correct / total) * 100
              valid_loss += loss.item()
          val_acc.append(val_accu/len(val_loader))
          val_loss.append(valid_loss/len(val_loader))
          
          
          print('Epoch [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%, Validation Loss : {:.4f}, Validation Accuracy : {:.2f}%,'.format(epoch + 1, num_epochs,lss/len(train_loader) ,accu/len(train_loader), valid_loss/len(val_loader), val_accu/len(val_loader)))
      print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
      return model, accuracy1, loss1,val_acc,val_loss

# %%
model1,accuracy1,loss1,val_acc1,val_loss1=train( model, train_loader,val_loader, criterion, optimizer,num_epochs=50)
# Out:
# Device: cuda:0
# Epoch [1/50], Loss: 3.2020, Accuracy: 11.41%, Validation Loss : 4.1322, Validation Accuracy : 11.33%,
# Epoch [2/50], Loss: 3.2617, Accuracy: 7.77%, Validation Loss : 3.1036, Validation Accuracy : 9.31%,
# Epoch [3/50], Loss: 3.0835, Accuracy: 10.66%, Validation Loss : 3.1203, Validation Accuracy : 9.81%,
# Epoch [4/50], Loss: 3.0533, Accuracy: 11.82%, Validation Loss : 3.0596, Validation Accuracy : 12.01%,
# Epoch [5/50], Loss: 2.9974, Accuracy: 13.57%, Validation Loss : 2.9962, Validation Accuracy : 11.64%,
# Epoch [6/50], Loss: 2.9719, Accuracy: 13.52%, Validation Loss : 2.9532, Validation Accuracy : 14.39%,
# Epoch [7/50], Loss: 2.9377, Accuracy: 14.52%, Validation Loss : 2.9639, Validation Accuracy : 13.04%,
# Epoch [8/50], Loss: 2.9290, Accuracy: 14.58%, Validation Loss : 3.0276, Validation Accuracy : 12.24%,
# Epoch [9/50], Loss: 2.8992, Accuracy: 15.57%, Validation Loss : 2.8930, Validation Accuracy : 14.15%,
# Epoch [10/50], Loss: 2.8819, Accuracy: 15.42%, Validation Loss : 2.8859, Validation Accuracy : 15.17%,
# Epoch [11/50], Loss: 2.8447, Accuracy: 16.68%, Validation Loss : 2.8786, Validation Accuracy : 16.38%,
# Epoch [12/50], Loss: 2.8301, Accuracy: 17.17%, Validation Loss : 2.8565, Validation Accuracy : 17.06%,
# Epoch [13/50], Loss: 2.7852, Accuracy: 18.56%, Validation Loss : 2.8596, Validation Accuracy : 15.94%,
# Epoch [14/50], Loss: 2.7523, Accuracy: 18.95%, Validation Loss : 2.7992, Validation Accuracy : 17.97%,
# Epoch [15/50], Loss: 2.6847, Accuracy: 20.65%, Validation Loss : 2.6806, Validation Accuracy : 19.71%,
# Epoch [16/50], Loss: 2.6625, Accuracy: 20.94%, Validation Loss : 2.6550, Validation Accuracy : 20.73%,
# Epoch [17/50], Loss: 2.5773, Accuracy: 23.64%, Validation Loss : 2.5918, Validation Accuracy : 22.45%,
# Epoch [18/50], Loss: 2.5366, Accuracy: 23.28%, Validation Loss : 2.6478, Validation Accuracy : 21.05%,
# Epoch [19/50], Loss: 2.4795, Accuracy: 26.01%, Validation Loss : 2.5737, Validation Accuracy : 23.67%,
# Epoch [20/50], Loss: 2.4200, Accuracy: 26.03%, Validation Loss : 2.5666, Validation Accuracy : 24.64%,
# Epoch [21/50], Loss: 2.3965, Accuracy: 26.74%, Validation Loss : 2.5327, Validation Accuracy : 24.58%,
# Epoch [22/50], Loss: 2.3576, Accuracy: 29.07%, Validation Loss : 2.4469, Validation Accuracy : 24.60%,
# Epoch [23/50], Loss: 2.2858, Accuracy: 29.65%, Validation Loss : 2.4557, Validation Accuracy : 26.78%,
# Epoch [24/50], Loss: 2.2796, Accuracy: 30.59%, Validation Loss : 2.4306, Validation Accuracy : 26.80%,
# Epoch [25/50], Loss: 2.2246, Accuracy: 32.90%, Validation Loss : 2.4016, Validation Accuracy : 27.24%,
# Epoch [26/50], Loss: 2.1510, Accuracy: 33.89%, Validation Loss : 2.3643, Validation Accuracy : 27.81%,
# Epoch [27/50], Loss: 2.0841, Accuracy: 36.70%, Validation Loss : 2.3687, Validation Accuracy : 30.10%,
# Epoch [28/50], Loss: 2.0534, Accuracy: 38.03%, Validation Loss : 2.4113, Validation Accuracy : 29.15%,
# Epoch [29/50], Loss: 1.9741, Accuracy: 39.22%, Validation Loss : 2.3506, Validation Accuracy : 30.45%,
# Epoch [30/50], Loss: 1.9183, Accuracy: 40.19%, Validation Loss : 2.4678, Validation Accuracy : 27.79%,
# Epoch [31/50], Loss: 1.8901, Accuracy: 42.16%, Validation Loss : 2.3613, Validation Accuracy : 29.99%,
# Epoch [32/50], Loss: 1.7579, Accuracy: 45.43%, Validation Loss : 2.4083, Validation Accuracy : 30.66%,
# Epoch [33/50], Loss: 1.7065, Accuracy: 47.83%, Validation Loss : 2.4580, Validation Accuracy : 29.43%,
# Epoch [34/50], Loss: 1.6743, Accuracy: 47.90%, Validation Loss : 2.4121, Validation Accuracy : 30.96%,
# Epoch [35/50], Loss: 1.5722, Accuracy: 51.31%, Validation Loss : 2.4311, Validation Accuracy : 30.04%,
# Epoch [36/50], Loss: 1.4992, Accuracy: 53.10%, Validation Loss : 2.5050, Validation Accuracy : 32.56%,
# Epoch [37/50], Loss: 1.3868, Accuracy: 57.70%, Validation Loss : 2.6158, Validation Accuracy : 31.38%,
# Epoch [38/50], Loss: 1.3315, Accuracy: 58.17%, Validation Loss : 2.6561, Validation Accuracy : 30.20%,
# Epoch [39/50], Loss: 1.1723, Accuracy: 62.51%, Validation Loss : 2.8261, Validation Accuracy : 29.24%,
# Epoch [40/50], Loss: 1.1033, Accuracy: 64.08%, Validation Loss : 2.7750, Validation Accuracy : 31.48%,
# Epoch [41/50], Loss: 0.9595, Accuracy: 70.45%, Validation Loss : 2.8949, Validation Accuracy : 32.07%,
# Epoch [42/50], Loss: 0.8640, Accuracy: 72.05%, Validation Loss : 3.0804, Validation Accuracy : 31.06%,
# Epoch [43/50], Loss: 0.7425, Accuracy: 75.25%, Validation Loss : 3.5386, Validation Accuracy : 33.76%,
# Epoch [44/50], Loss: 0.7099, Accuracy: 76.98%, Validation Loss : 3.5007, Validation Accuracy : 30.76%,
# Epoch [45/50], Loss: 0.6396, Accuracy: 78.78%, Validation Loss : 3.4873, Validation Accuracy : 31.86%,
# Epoch [46/50], Loss: 0.6777, Accuracy: 78.66%, Validation Loss : 3.3977, Validation Accuracy : 32.79%,
# Epoch [47/50], Loss: 0.5135, Accuracy: 83.11%, Validation Loss : 3.7458, Validation Accuracy : 30.95%,
# Epoch [48/50], Loss: 0.3941, Accuracy: 87.09%, Validation Loss : 4.2441, Validation Accuracy : 31.70%,
# Epoch [49/50], Loss: 0.3524, Accuracy: 88.61%, Validation Loss : 4.2758, Validation Accuracy : 31.64%,
# Epoch [50/50], Loss: 0.3685, Accuracy: 88.05%, Validation Loss : 4.1425, Validation Accuracy : 31.55%,
# ######## Training Finished in 2241.705287218094 seconds ###########

# %%
model1.eval() 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model1 = model1.to(device)
with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model1(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print('Test Accuracy of the model on the {} test images: {} %'
        .format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 989 test images: 31.749241658240646 %

# %%
torch.save(model1, 'model_googlenet1.pt')
#model = torch.load('model_googlenet1.pt')
#model.eval()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.plot(loss1,label='train loss')
plt.plot(val_loss1,label='val loss')
    
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy1,label='train accuracy')
plt.plot(val_acc1,label='val accuracy')    
plt.legend()

# %%
#confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
y_true = []
y_pred = []
 
for data in test_loader:
  images,labels=data[0].to(device),data[1]
  y_true.extend(labels.numpy())
  outputs=model1(images)
  _, predicted = torch.max(outputs, 1)
  y_pred.extend(predicted.cpu().numpy())

cf_matrix = confusion_matrix(y_true, y_pred)
class_names = ('SUGAR', 'TOMATO_SAUCE', 'SPICES', 'WATER',
           'VINEGAR', 'TEA', 'RICE', 'PASTA', 'OIL', 'SODA','CORN','HONEY','FLOUR','JUICE','MILK','NUTS','COFFEE','JAM','CHOCOLATE','FISH','CANDY','CHIPS','BEANS','CAKE','CEREAL')
 
# Create pandas dataframe
dataframe = pd.DataFrame(cf_matrix, index=class_names, columns=class_names)

plt.figure(figsize=(8, 6))
 
# Create heatmap
sns.heatmap(dataframe, annot=True, cbar=None,cmap="YlGnBu",fmt="d")
 
plt.title("Confusion Matrix"), plt.tight_layout()
 
plt.ylabel("True Class"), 
plt.xlabel("Predicted Class")
plt.show()

# %%
#classification Report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#        SUGAR       0.35      0.29      0.31        28
# TOMATO_SAUCE       0.32      0.45      0.38        22
#       SPICES       0.48      0.54      0.51        83
#        WATER       0.17      0.11      0.13        53
#      VINEGAR       0.29      0.15      0.20        27
#          TEA       0.34      0.26      0.29        66
#         RICE       0.21      0.22      0.21        69
#        PASTA       0.09      0.07      0.08        15
#          OIL       0.19      0.14      0.16        21
#         SODA       0.22      0.14      0.17        28
#         CORN       0.30      0.16      0.21        38
#        HONEY       0.38      0.60      0.46        47
#        FLOUR       0.21      0.41      0.28        58
#        JUICE       0.16      0.20      0.18        35
#         MILK       0.27      0.46      0.34        35
#         NUTS       0.29      0.11      0.16        36
#       COFFEE       0.26      0.35      0.30        34
#          JAM       0.43      0.29      0.35        34
#    CHOCOLATE       0.12      0.08      0.10        36
#         FISH       0.32      0.14      0.19        43
#        CANDY       0.38      0.30      0.33        20
#        CHIPS       0.28      0.31      0.29        52
#        BEANS       0.38      0.50      0.43        28
#         CAKE       0.50      0.36      0.42        28
#       CEREAL       0.55      0.58      0.57        53
#
#     accuracy                           0.31       989
#    macro avg       0.30      0.29      0.28       989
# weighted avg       0.31      0.31      0.30       989

# %% [markdown]
# Transfer Learning on Freiburg Dataset with Googlenet pretrained weights

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'googlenet',pretrained=True)
optimizer = torch.optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
model,accuracy1,loss1, val_acc1, val_loss1=train( model, train_loader,val_loader, criterion, optimizer,num_epochs=50)
# Out:
# Device: cuda:0
# Epoch [1/50], Loss: 1.9217, Accuracy: 50.35%, Validation Loss : 1.3438, Validation Accuracy : 61.28%,
# Epoch [2/50], Loss: 3.2495, Accuracy: 8.88%, Validation Loss : 3.2543, Validation Accuracy : 5.46%,
# Epoch [3/50], Loss: 3.2183, Accuracy: 6.24%, Validation Loss : 3.2030, Validation Accuracy : 7.89%,
# Epoch [4/50], Loss: 3.1880, Accuracy: 6.92%, Validation Loss : 3.1785, Validation Accuracy : 6.17%,
# Epoch [5/50], Loss: 3.1806, Accuracy: 7.22%, Validation Loss : 3.2020, Validation Accuracy : 5.76%,
# Epoch [6/50], Loss: 3.1884, Accuracy: 7.28%, Validation Loss : 3.2328, Validation Accuracy : 5.47%,
# Epoch [7/50], Loss: 3.1840, Accuracy: 7.22%, Validation Loss : 3.2042, Validation Accuracy : 7.87%,
# Epoch [8/50], Loss: 3.1834, Accuracy: 5.72%, Validation Loss : 3.2232, Validation Accuracy : 4.85%,
# Epoch [9/50], Loss: 3.1854, Accuracy: 6.62%, Validation Loss : 3.1782, Validation Accuracy : 5.49%,
# Epoch [10/50], Loss: 3.1818, Accuracy: 5.92%, Validation Loss : 3.1814, Validation Accuracy : 4.54%,
# Epoch [11/50], Loss: 3.1809, Accuracy: 6.92%, Validation Loss : 3.1802, Validation Accuracy : 4.57%,
# Epoch [12/50], Loss: 3.1752, Accuracy: 6.81%, Validation Loss : 3.1791, Validation Accuracy : 5.44%,
# Epoch [13/50], Loss: 3.1772, Accuracy: 6.53%, Validation Loss : 3.1824, Validation Accuracy : 7.88%,
# Epoch [14/50], Loss: 3.1728, Accuracy: 6.65%, Validation Loss : 3.1933, Validation Accuracy : 5.44%,
# Epoch [15/50], Loss: 3.1747, Accuracy: 7.37%, Validation Loss : 3.1861, Validation Accuracy : 5.46%,
# Epoch [16/50], Loss: 3.1710, Accuracy: 6.38%, Validation Loss : 3.1841, Validation Accuracy : 5.46%,
# Epoch [17/50], Loss: 3.1648, Accuracy: 8.07%, Validation Loss : 3.2201, Validation Accuracy : 5.46%,
# Epoch [18/50], Loss: 3.1728, Accuracy: 6.70%, Validation Loss : 3.1940, Validation Accuracy : 4.57%,
# Epoch [19/50], Loss: 3.1729, Accuracy: 7.25%, Validation Loss : 3.1803, Validation Accuracy : 5.45%,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-25e7c62d34a0> in <module>
# ----> 1 model,accuracy1,loss1, val_acc1, val_loss1=train( model, train_loader,val_loader, criterion, optimizer,num_epochs=50)
#
# <ipython-input-30-e1a827cdfaf2> in train(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      23               optimizer.zero_grad()
#      24               loss.backward()
# ---> 25               optimizer.step()
#      26               # Train accuracy
#      27               total = labels.size(0)
#
# /usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     138                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139                 with torch.autograd.profiler.record_function(profile_name):
# --> 140                     out = func(*args, **kwargs)
#     141                     obj._optimizer_step_code()
#     142                     return out
#
# /usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      21         try:
#      22             torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 23             ret = func(self, *args, **kwargs)
#      24         finally:
#      25             torch.set_grad_enabled(prev_grad)
#
# /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py in step(self, closure, grad_scaler)
#     232                     state_steps.append(state['step'])
#     233
# --> 234             adam(params_with_grad,
#     235                  grads,
#     236                  exp_avgs,
#
# /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     298         func = _single_tensor_adam
#     299
# --> 300     func(params,
#     301          grads,
#     302          exp_avgs,
#
# /usr/local/lib/python3.8/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     408                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     409             else:
# --> 410                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     411
#     412             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

num_epochs= 50
plt.figure()
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss plot')
epochs = [i for i in range(num_epochs)]

plt.plot(loss1,label='train loss')
plt.plot(val_loss1,label='val loss')
    
plt.legend()

# %%
import matplotlib.pyplot as plt

num_epochs= 50
plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy1,label='train accuracy')
plt.plot(val_acc1,label='val accuracy')    
plt.legend()

# %%
model.eval() 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print('Test Accuracy of the model on the {} test images: {} %'
        .format(total, (correct / total) * 100))

# %%
torch.save(model, 'model_googlenet1_transfer.pt')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_true = []
y_pred = []
 
for data in test_loader:
  images,labels=data[0].to(device),data[1]
  y_true.extend(labels.numpy())
  outputs=model(images)
  _, predicted = torch.max(outputs, 1)
  y_pred.extend(predicted.cpu().numpy())

cf_matrix = confusion_matrix(y_true, y_pred)
class_names = ('SUGAR', 'TOMATO_SAUCE', 'SPICES', 'WATER',
           'VINEGAR', 'TEA', 'RICE', 'PASTA', 'OIL', 'SODA','CORN','HONEY','FLOUR','JUICE','MILK','NUTS','COFFEE','JAM','CHOCOLATE','FISH','CANDY','CHIPS','BEANS','CAKE','CEREAL')
 
# Create pandas dataframe
dataframe = pd.DataFrame(cf_matrix, index=class_names, columns=class_names)

plt.figure(figsize=(8, 6))
 
# Create heatmap
sns.heatmap(dataframe, annot=True, cbar=None,cmap="YlGnBu",fmt="d")
 
plt.title("Confusion Matrix"), plt.tight_layout()
 
plt.ylabel("True Class"), 
plt.xlabel("Predicted Class")
plt.show()

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=class_names))

# %% [markdown]
# Googlenet on Grocery Dataset

# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as td
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from matplotlib import image
from matplotlib import pyplot
import time
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_data_grocery_store(path, batch_size, input_size):
    
    transform_dict={'src':transforms.Compose([transforms.CenterCrop(224), transforms.RandomRotation(5), transforms.RandomHorizontalFlip(),
                                              transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])}
    data1 = datasets.ImageFolder(root=path,transform=transform_dict['src'])
    data_loader=td.DataLoader(data1,batch_size,shuffle=True,drop_last=False,num_workers=0)  
    return data_loader

train_loader2=load_data_grocery_store(path=r'/content/drive/MyDrive/Project/Dataset/Grocery_store_dataset/Train', batch_size=32, input_size=[224,224])
test_loader2=load_data_grocery_store(path=r'/content/drive/MyDrive/Project/Dataset/Grocery_store_dataset/Test', batch_size=32, input_size=[224,224])
val_loader2=load_data_grocery_store(path=r'/content/drive/MyDrive/Project/Dataset/Grocery_store_dataset/Val', batch_size=32, input_size=[224,224])

# %%
plot_data_loader(train_loader2,(2,2))

# %%
model2 = torch.hub.load('pytorch/vision:v0.10.0', 'googlenet')
optimizer2 = torch.optim.Adam(model2.parameters())
criterion2 = nn.CrossEntropyLoss()
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
def train( model, train_loader,val_loader, criterion, optimizer,num_epochs):
      device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
      print("Device: {}".format(device))
      model.to(device)
      model.aux_logits=False
      total_steps = len(train_loader)
      t1 = time.time()
      accuracy1 = []
      loss1 = []
      val_acc=[]
      val_loss=[]
      for epoch in range(num_epochs):
          accu = 0
          lss = 0
          val_accu=0
          valid_loss=0
          for i,data in enumerate(train_loader):
              images, labels = data[0].to(device), data[1].to(device)
              # Forward pass
              outputs = model(images)
              loss = criterion(outputs, labels)
              # Backprop and optimisation
              optimizer.zero_grad()
              loss.backward()
              optimizer.step()
              # Train accuracy
              total = labels.size(0)
              _,predicted = torch.max(outputs.data, 1)
              correct = (predicted == labels).sum().item()
              accu += (correct / total) * 100
              lss += loss.item()
          model.eval()  
          for i, data in enumerate(val_loader):
              val_images, val_labels = data[0].to(device), data[1].to(device)
              outputs = model(val_images)
              loss = criterion(outputs, val_labels)
              # Val accuracy
              total = val_labels.size(0)
              _,predicted = torch.max(outputs.data, 1)
              correct = (predicted == val_labels).sum().item()
              val_accu += (correct / total) * 100
              valid_loss += loss.item()
          val_acc.append(val_accu/len(val_loader))
          val_loss.append(valid_loss/len(val_loader))
          accuracy1.append(accu/len(train_loader))
          loss1.append(lss/len(train_loader))
          
          print('Epoch [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%, Validation Loss : {:.4f}, Validation Accuracy : {:.2f}%,'.format(epoch + 1, num_epochs,lss/len(train_loader) ,accu/len(train_loader), valid_loss/len(val_loader), val_accu/len(val_loader)))
      print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
      return model, accuracy1, loss1,val_acc,val_loss

# %%
model2,accuracy2,loss2,val_acc2,val_loss2=train(model2, train_loader2,val_loader2, criterion2, optimizer2,num_epochs=50)
# Out:
# Device: cuda:0
# Epoch [1/50], Loss: 2.9895, Accuracy: 18.97%, Validation Loss : 3.3650, Validation Accuracy : 13.35%,
# Epoch [2/50], Loss: 2.9932, Accuracy: 15.44%, Validation Loss : 2.7839, Validation Accuracy : 14.12%,
# Epoch [3/50], Loss: 2.6658, Accuracy: 20.83%, Validation Loss : 2.7390, Validation Accuracy : 11.59%,
# Epoch [4/50], Loss: 2.4240, Accuracy: 23.70%, Validation Loss : 2.6008, Validation Accuracy : 18.29%,
# Epoch [5/50], Loss: 2.1916, Accuracy: 28.16%, Validation Loss : 2.4022, Validation Accuracy : 21.25%,
# Epoch [6/50], Loss: 1.9917, Accuracy: 33.43%, Validation Loss : 2.4342, Validation Accuracy : 20.78%,
# Epoch [7/50], Loss: 1.9341, Accuracy: 35.22%, Validation Loss : 2.1191, Validation Accuracy : 26.61%,
# Epoch [8/50], Loss: 1.7959, Accuracy: 38.85%, Validation Loss : 2.2491, Validation Accuracy : 25.70%,
# Epoch [9/50], Loss: 1.7133, Accuracy: 41.99%, Validation Loss : 2.0764, Validation Accuracy : 28.68%,
# Epoch [10/50], Loss: 1.6161, Accuracy: 44.88%, Validation Loss : 1.7515, Validation Accuracy : 42.82%,
# Epoch [11/50], Loss: 1.4984, Accuracy: 48.26%, Validation Loss : 1.8278, Validation Accuracy : 35.97%,
# Epoch [12/50], Loss: 1.4596, Accuracy: 49.94%, Validation Loss : 2.1183, Validation Accuracy : 33.28%,
# Epoch [13/50], Loss: 1.4130, Accuracy: 48.99%, Validation Loss : 1.6675, Validation Accuracy : 41.29%,
# Epoch [14/50], Loss: 1.3212, Accuracy: 53.77%, Validation Loss : 1.7740, Validation Accuracy : 41.75%,
# Epoch [15/50], Loss: 1.3039, Accuracy: 53.96%, Validation Loss : 1.6834, Validation Accuracy : 43.21%,
# Epoch [16/50], Loss: 1.2829, Accuracy: 55.29%, Validation Loss : 1.7045, Validation Accuracy : 45.05%,
# Epoch [17/50], Loss: 1.1781, Accuracy: 59.33%, Validation Loss : 1.5456, Validation Accuracy : 46.32%,
# Epoch [18/50], Loss: 1.1952, Accuracy: 57.74%, Validation Loss : 1.6391, Validation Accuracy : 42.98%,
# Epoch [19/50], Loss: 1.1369, Accuracy: 60.26%, Validation Loss : 1.5138, Validation Accuracy : 51.56%,
# Epoch [20/50], Loss: 1.0831, Accuracy: 62.14%, Validation Loss : 1.7780, Validation Accuracy : 45.47%,
# Epoch [21/50], Loss: 1.0587, Accuracy: 62.73%, Validation Loss : 1.5440, Validation Accuracy : 51.42%,
# Epoch [22/50], Loss: 1.0467, Accuracy: 63.71%, Validation Loss : 1.4611, Validation Accuracy : 53.49%,
# Epoch [23/50], Loss: 0.9706, Accuracy: 65.91%, Validation Loss : 1.4688, Validation Accuracy : 52.31%,
# Epoch [24/50], Loss: 0.9783, Accuracy: 66.51%, Validation Loss : 1.4373, Validation Accuracy : 53.04%,
# Epoch [25/50], Loss: 0.9476, Accuracy: 67.09%, Validation Loss : 1.4890, Validation Accuracy : 50.95%,
# Epoch [26/50], Loss: 0.8955, Accuracy: 67.85%, Validation Loss : 1.5658, Validation Accuracy : 50.64%,
# Epoch [27/50], Loss: 0.8275, Accuracy: 70.80%, Validation Loss : 1.3992, Validation Accuracy : 56.01%,
# Epoch [28/50], Loss: 0.7850, Accuracy: 72.98%, Validation Loss : 1.5333, Validation Accuracy : 53.15%,
# Epoch [29/50], Loss: 0.7980, Accuracy: 72.34%, Validation Loss : 1.5858, Validation Accuracy : 52.92%,
# Epoch [30/50], Loss: 0.6600, Accuracy: 75.63%, Validation Loss : 1.4794, Validation Accuracy : 56.45%,
# Epoch [31/50], Loss: 0.7141, Accuracy: 74.68%, Validation Loss : 1.3019, Validation Accuracy : 57.82%,
# Epoch [32/50], Loss: 0.5896, Accuracy: 78.82%, Validation Loss : 1.6673, Validation Accuracy : 57.22%,
# Epoch [33/50], Loss: 0.7074, Accuracy: 74.58%, Validation Loss : 1.4593, Validation Accuracy : 55.87%,
# Epoch [34/50], Loss: 0.6404, Accuracy: 77.49%, Validation Loss : 1.4436, Validation Accuracy : 59.44%,
# Epoch [35/50], Loss: 0.4998, Accuracy: 81.96%, Validation Loss : 1.4278, Validation Accuracy : 63.74%,
# Epoch [36/50], Loss: 0.5228, Accuracy: 81.32%, Validation Loss : 1.5270, Validation Accuracy : 60.21%,
# Epoch [37/50], Loss: 0.5362, Accuracy: 80.69%, Validation Loss : 1.3581, Validation Accuracy : 62.09%,
# Epoch [38/50], Loss: 0.4318, Accuracy: 84.61%, Validation Loss : 1.5528, Validation Accuracy : 64.19%,
# Epoch [39/50], Loss: 0.4547, Accuracy: 83.73%, Validation Loss : 1.5799, Validation Accuracy : 62.99%,
# Epoch [40/50], Loss: 0.4404, Accuracy: 83.86%, Validation Loss : 1.5483, Validation Accuracy : 62.57%,
# Epoch [41/50], Loss: 0.4400, Accuracy: 84.34%, Validation Loss : 1.6575, Validation Accuracy : 59.00%,
# Epoch [42/50], Loss: 0.4237, Accuracy: 85.75%, Validation Loss : 1.6725, Validation Accuracy : 63.00%,
# Epoch [43/50], Loss: 0.3874, Accuracy: 86.52%, Validation Loss : 1.6749, Validation Accuracy : 61.81%,
# Epoch [44/50], Loss: 0.4378, Accuracy: 85.68%, Validation Loss : 1.6637, Validation Accuracy : 59.90%,
# Epoch [45/50], Loss: 0.4540, Accuracy: 84.10%, Validation Loss : 1.3980, Validation Accuracy : 65.68%,
# Epoch [46/50], Loss: 0.3818, Accuracy: 86.87%, Validation Loss : 1.4429, Validation Accuracy : 67.71%,
# Epoch [47/50], Loss: 0.3442, Accuracy: 88.10%, Validation Loss : 1.7315, Validation Accuracy : 65.80%,
# Epoch [48/50], Loss: 0.2462, Accuracy: 91.56%, Validation Loss : 1.6320, Validation Accuracy : 66.41%,
# Epoch [49/50], Loss: 0.2531, Accuracy: 91.24%, Validation Loss : 1.7603, Validation Accuracy : 66.26%,
# Epoch [50/50], Loss: 0.3075, Accuracy: 89.66%, Validation Loss : 1.5700, Validation Accuracy : 66.41%,
# ######## Training Finished in 1221.1273171901703 seconds ###########

# %%
model2.eval() 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model2 = model2.to(device)
with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader2:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model2(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print('Test Accuracy of the model on the {} test images: {} %'
        .format(total, (correct / total) * 100))

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.plot(loss2,label='Train Loss')
plt.plot(val_loss2,lable='Validation Loss')
plt.legend()

print(loss2)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# [1.4030278427036185, 3.228152135485097, 2.179536422616557, 1.6562528014183044, 1.1124927589767857, 0.9087635498297842, 0.5961370199526611, 0.6028931936935374, 0.4833240780587259, 0.5147232030959505, 0.3311333125947337, 0.37348188626530926, 0.2646281807438323, 0.2696243628467384, 0.28678885957618294, 0.14372990547532313, 0.2585854678365745, 0.12131534556024953, 0.21002292696778713, 0.20610764995217323, 0.2189514295835244, 0.17720600167338393, 0.23995535728203035, 0.19406641152148185, 0.15248837643057891, 0.14003729183030755, 0.08968408343284145, 0.17968951324368582, 0.031304099481770355, 0.1671643849641489, 0.14611316610764907, 0.23973283759857478, 0.19418481727571865, 0.09692428303012428, 0.11678615171235594, 0.01807564173903206, 0.012790569021538096, 0.013425467575488207, 0.15574193106716083, 0.1526101771068122, 0.18599683304905498, 0.14461679498689542, 0.13005956990558556, 0.11335960872728672, 0.01409572316295357, 0.001262606242993283, 0.0005271185509388344, 0.00032017699446011027, 0.0002493041571190253, 0.00016982985631617148]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy2,label='Train Accuracy')
plt.plot(val_acc2,label='Validation Accuracy')  
plt.legend()

print(accuracy2)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# [66.87987329434698, 14.897051656920077, 29.819992690058477, 43.99061890838207, 61.81164717348928, 69.4474902534113, 80.3149366471735, 80.15046296296296, 84.32931286549707, 83.48866959064327, 88.47161306042885, 88.3406432748538, 91.49153265107213, 91.5402655945419, 91.67884990253411, 95.05056042884989, 91.73824317738791, 96.44858674463937, 93.55506822612085, 93.11038011695906, 93.20784600389864, 94.9759381091618, 93.33120126705653, 93.90685916179338, 95.33838937621832, 95.64144736842105, 96.86738547758284, 94.31042884990252, 99.09539473684211, 95.47240497076022, 95.8470394736842, 93.54440789473684, 93.82462231968812, 97.16282894736842, 96.95723684210526, 99.50657894736842, 99.62231968810916, 99.62993421052632, 95.77546296296296, 95.01705653021443, 94.03021442495127, 95.30488547758284, 96.33284600389864, 96.4150828460039, 99.71217105263158, 100.0, 100.0, 100.0, 100.0, 100.0]

# %%
torch.save(model2, 'model_googlenet2.pt')

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
y_true = []
y_pred = []
 
for data in test_loader2:
  images,labels=data[0].to(device),data[1]
  y_true.extend(labels.numpy())
  outputs=model2(images)
  _, predicted = torch.max(outputs, 1)
  y_pred.extend(predicted.cpu().numpy())

cf_matrix = confusion_matrix(y_true, y_pred)
class_names = ('SUGAR', 'TOMATO_SAUCE', 'SPICES', 'WATER',
           'VINEGAR', 'TEA', 'RICE', 'PASTA', 'OIL', 'SODA','CORN','HONEY','FLOUR','JUICE','MILK','NUTS','COFFEE','JAM','CHOCOLATE','FISH','CANDY','CHIPS','BEANS','CAKE','CEREAL')
# Create pandas dataframe
dataframe = pd.DataFrame(cf_matrix, index=class_names, columns=class_names)

plt.figure(figsize=(8, 6))
 
# Create heatmap
sns.heatmap(dataframe, annot=True, cbar=None,cmap="YlGnBu",fmt="d")
 
plt.title("Confusion Matrix"), plt.tight_layout()
 
plt.ylabel("True Class"), 
plt.xlabel("Predicted Class")
plt.show()

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=class_names))
